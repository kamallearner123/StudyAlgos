# %%
def reverse( x):
    """
    :type x: int
    :rtype: int
    """
    final = 0
        
    if x < 0:
        remain = x*(-1)
    else:
        remain = x
    power = 0
    while remain != 0:
        final = remain%10 + (final * (10))
        power += 1
        remain = remain//10
        print("final = {}, remain = {}".format(final,remain))

    if final > 2**31:
        return 0
    elif final < -(2**31+1):
        return 0
    
    elif x<0:
        return final*(-1)
    else:
        return final
    
reverse(1534236469)
# Out:
# final = 9, remain = 153423646
# final = 96, remain = 15342364
# final = 964, remain = 1534236
# final = 9646, remain = 153423
# final = 96463, remain = 15342
# final = 964632, remain = 1534
# final = 9646324, remain = 153
# final = 96463243, remain = 15
# final = 964632435, remain = 1
# final = 9646324351, remain = 0
# 0

# %%
2**32 > 9646324351
# Out:
# False

# %%
def reverse( x):
    """
    :type x: int
    :rtype: int
    """
    final = 0
    
    if x < 0:
        remain = x*(-1)
    else:
        remain = x
    
    y = str(remain)
    final = int(y[::-1])
    if final > 2**31:
        return 0
    elif final < -(2**31+1):
        return 0
    
    elif x<0:
        return final*(-1)
    else:
        return final
    
reverse(-123)
# Out:
# -321

# %%
class Solution(object):
        
    def threeSum(self, nums):
        """
        :type nums: List[int]
        :rtype: List[List[int]]
        """
        if len(nums) == 3:
            return []
        
        finalList = set()
        nums.sort()
        n = len(nums)
        answer = []
        for i in range(n-2):
            a = nums[i]
            start = i+1
            end = n - 1
            b = nums[start]
            c = nums[end]
            while start<end:

                if a+b+c > 0:
                    end -=1
                elif a+b+c < 0:
                    start += 1
                else:
                    finalList.add((a,b,c))
                    start += 1
                    end -= 1
                b = nums[start]
                c = nums[end]
                
        for item in finalList:
            answer.append(list(item))
        return answer

                    
obj = Solution()
obj.threeSum([-1,0,1,2,-1,-4])
# Out:
# [[-1, 0, 1], [-1, -1, 2]]

# %%
sorted([0, 3, -3]) == sorted([0, -3, 3])
# Out:
# True

# %% [markdown]
# 16. 3Sum Closest
# Medium
#
# 5494
#
# 237
#
# Add to List
#
# Share
# Given an integer array nums of length n and an integer target, find three integers in nums such that the sum is closest to target.
#
# Return the sum of the three integers.
#
# You may assume that each input would have exactly one solution.
#
#
#
# Example 1:
#
# Input: nums = [-1,2,1,-4], target = 1
# Output: 2
# Explanation: The sum that is closest to the target is 2. (-1 + 2 + 1 = 2).
# Example 2:
#
# Input: nums = [0,0,0], target = 1
# Output: 0

# %%
class Solution(object):
    def threeSumClosest(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: i"""
        n = len(nums)
        
        nums.sort()        
    
        min_diff = float('inf')
        
        for i in range(n-2):#[-10,-5,0,20,40,50,60]
            a = nums[i]
            end = n-1
            start = i+1
            while start < end:
                b = nums[start]
                c = nums[end]
                
                #if tmp_diff < result_diff: then swap
                #100 - 20,30,56 =  6;  result_diff 20
                tmp_diff = abs((target) - (a+b+c))
                if  tmp_diff < min_diff:
                    #print(a,b,c," diff = ", tmp_diff)
                    result = a+b+c
                    min_diff = tmp_diff                    
                    
                if  a+b+c > target:
                    end -=1
                elif a+b+c < target:
                    start +=1
                else:
                    return a+b+c
        
        return result

s1 = Solution()
s1.threeSumClosest(nums = [1,-3,3,5,4,1], target = 1)
# Out:
# [-3, 1, 1, 3, 4, 5]
# 1

# %%
l = [1,1,1,0]
l.sort()
print(l)
# Out:
# [0, 1, 1, 1]

# %%
list1 = [1,-3,3,5,4,1,40,-10,-6,100,98,1,1,1]
list1.sort()
print(list1)

#n**3 => n**2
for i in range(len(list1)-2):
    for j in range(i+1, len(list1)-1):
        for k in range(j+1, len(list1)):
            print(list1[i],list1[j],list1[k])
# Out:
# [-10, -6, -3, 1, 1, 1, 1, 1, 3, 4, 5, 40, 98, 100]
# -10 -6 -3
# -10 -6 1
# -10 -6 1
# -10 -6 1
# -10 -6 1
# -10 -6 1
# -10 -6 3
# -10 -6 4
# -10 -6 5
# -10 -6 40
# -10 -6 98
# -10 -6 100
# -10 -3 1
# -10 -3 1
# -10 -3 1
# -10 -3 1
# -10 -3 1
# -10 -3 3
# -10 -3 4
# -10 -3 5
# -10 -3 40
# -10 -3 98
# -10 -3 100
# -10 1 1
# -10 1 1
# -10 1 1
# -10 1 1
# -10 1 3
# -10 1 4
# -10 1 5
# -10 1 40
# -10 1 98
# -10 1 100
# -10 1 1
# -10 1 1
# -10 1 1
# -10 1 3
# -10 1 4
# -10 1 5
# -10 1 40
# -10 1 98
# -10 1 100
# -10 1 1
# -10 1 1
# -10 1 3
# -10 1 4
# -10 1 5
# -10 1 40
# -10 1 98
# -10 1 100
# -10 1 1
# -10 1 3
# -10 1 4
# -10 1 5
# -10 1 40
# -10 1 98
# -10 1 100
# -10 1 3
# -10 1 4
# -10 1 5
# -10 1 40
# -10 1 98
# -10 1 100
# -10 3 4
# -10 3 5
# -10 3 40
# -10 3 98
# -10 3 100
# -10 4 5
# -10 4 40
# -10 4 98
# -10 4 100
# -10 5 40
# -10 5 98
# -10 5 100
# -10 40 98
# -10 40 100
# -10 98 100
# -6 -3 1
# -6 -3 1
# -6 -3 1
# -6 -3 1
# -6 -3 1
# -6 -3 3
# -6 -3 4
# -6 -3 5
# -6 -3 40
# ...
